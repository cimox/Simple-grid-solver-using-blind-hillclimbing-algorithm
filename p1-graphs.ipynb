# %%
setwd("/Users/cimo/_EA/project 1/hillclimbing")

# %%
data <- read.csv("graphs-data/max-8000_size-20_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="4x5 Grid, Max. 50k generations, Simple stagnation, Distance = 1", 
     ylab="Fitness", xlab="Generation")
# Out:
# Plot with title “4x5 Grid, Max. 50k generations”

# %%
data <- read.csv("../graphs-data/max-11000_size-20_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="4x5 Grid, Max. 50k generations, No stagnation, distance = 1", 
     ylab="Fitness", xlab="Generation", ,lwd=1.5, col="red"
    )
# Out:
# Plot with title “4x5 Grid, Max. 50k generations, No stagnation, distance = 1”

# %%
data <- read.csv("../graphs-data/max-18000_size-20_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="4x5 Grid, Max. 50k generations, Stagnation + distance", 
     ylab="Fitness", xlab="Generation", ,lwd=1.5, col="red"
    )
# Out:
# Plot with title “4x5 Grid, Max. 50k generations, Stagnation + distance”

# %%
data <- read.csv("../graphs-data/max-11000_size-20_D-1.out", header=T, sep=";")
data2 <- read.csv("../graphs-data/max-18000_size-20_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="4x5 Grid, Max. 50k generations. Stagnation vs No stagnation", 
     ylab="Fitness", xlab="Generation", col="red", lwd=1.5     
    )
lines(data2$iter,data2$fitness,type="s", col="blue", lwd=1.5)
legend('bottomright',
        c("Distance - False", "Distance - True"),
        lwd=c(1.5,1.5),
        col=c("red","blue")
      )
# Out:
# Plot with title “4x5 Grid, Max. 50k generations. Stagnation vs No stagnation”

# %%
data <- read.csv("../graphs-data/max-50000_size-25_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="5x5 Grid, Max. 50k generations, no stagnation, distance = 1", 
     ylab="Fitness", xlab="Generation", lwd=1.5, col="red"
    )
# Out:
# Plot with title “5x5 Grid, Max. 50k generations, no stagnation, distance = 1”

# %%
data <- read.csv("../graphs-data/max-50000_size-25_D-1_v2.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="5x5 Grid, Max. 50k generations, stagnation + distance", 
     ylab="Fitness", xlab="Generation", lwd=1.5, col="red"
    )
# Out:
# Plot with title “5x5 Grid, Max. 50k generations, stagnation + distance”

# %%
data <- read.csv("../graphs-data/max-50000_size-25_D-1_v3.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="5x5 Grid, Max. 50k generations, stagnation + distance", 
     ylab="Fitness", xlab="Generation", lwd=1.5, col="red"
    )
# Out:
# Plot with title “5x5 Grid, Max. 50k generations, stagnation + distance”

# %%
data <- read.csv("../graphs-data/max-100000_size-40_D-1.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="5x8 Grid, Max. 100k generations, stagnation", 
     ylab="Fitness", xlab="Generation", lwd=1.5, col="red", ylim=c(10,40)
    )
data2 <- read.csv("../graphs-data/max-100000_size-40_D-10.out", header=T, sep=";")
lines(data2$iter,data2$fitness,type="s", lwd=1.5, col="blue")

legend('bottomright',
        c("Distance = False", "Distance = True"),
        lwd=c(1.5,1.5),
        col=c("red","blue")
      )
# Out:
# Plot with title “5x8 Grid, Max. 100k generations, stagnation”

# %%
data <- read.csv("../graphs-data/max_size-40_TT.out", header=T, sep=";")
plot(data$iter,data$fitness,type="s", main="5x8 Grid, Max. 1Mil generations, stagnation", 
     ylab="Fitness", xlab="Generation", lwd=1.5, col="blue", ylim=c(20,40)
    )
data2 <- read.csv("../graphs-data/max_size-40_FT.out", header=T, sep=";")
lines(data2$iter,data2$fitness,type="s", lwd=1.5, col="red")

legend('bottomright',
        c("Distance - False", "Distance - True"),
        lwd=c(1.5,1.5),
        col=c("red","blue")
      )
# Out:
# Plot with title “5x8 Grid, Max. 1Mil generations, stagnation”
